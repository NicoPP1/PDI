# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoPP1/PDI/blob/main/Pr%C3%A1ctico_N%C2%BA2_Parma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción
# En el presente trabajo se desarrolla la actividad práctica Nº2, en donde en la primer sección se busca manipular las componentes luminancia y saturación de una imagen.
#
# En la segunda sección se modificarán los mapcolor de una imagen.

# %%
#Librerias
import imageio
import numpy as np
import matplotlib.pyplot as plt

#importo imagen
img = imageio.imread('lenna.jpg')

def checkY(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if mat[i,j] > 1:
              flag = False
  return flag


def checkI(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if (I[i,j] >= 0.5957) or (I[i,j] <= -0.5957):
              flag = False
  return flag

def checkQ(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if (Q[i,j] >= 0.5226) or (Q[i,j] <= -0.5226):
              flag = False
  return flag


def RGB2YIQ(img):
  r = img[:,:,0]/255
  g = img[:,:,1]/255
  b = img[:,:,2]/255

  Y = (r*0.299+g*0.587+b*0.114)
  I = (r*0.595716-g*0.274453-b*0.321263)
  Q = (r*0.211456-g*0.522591+b*0.311135)

  return(Y,I,Q)

def YIQ2RGB(Y,I,Q):
  if (checkY(Y) and (checkI(I)) and checkQ(Q)):
    r_conv = (Y+0.9563*I+0.621*Q)*255
    g_conv = (Y-0.2721*I-0.6474*Q)*255
    b_conv = (Y-1.1070*I+1.7046*Q)*255

    img = np.dstack((r_conv,g_conv,b_conv)).round(decimals = 0)
    img = img.astype('uint8')  

    return(img)
  else:
    print("No se cumple condición amplitud YIQ")


Y,I,Q = RGB2YIQ(img)
alpha = 1 #@param {type:"slider", min:0, max:2, step:0.1}
beta = 0 #@param {type:"slider", min:0, max:2, step:0.1}
img_mod = YIQ2RGB(alpha*Y,beta*I,beta*Q)
plt.imshow(img_mod)

# %% [markdown]
# Mapas de colores

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt

arg = imageio.imread('arg.jpg')
def checkY(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if mat[i,j] > 1:
              flag = False
  return flag


def checkI(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if (I[i,j] >= 0.5957) or (I[i,j] <= -0.5957):
              flag = False
  return flag

def checkQ(mat):
  flag = True
  for i in range(img.shape[0]):
      for j in range(img.shape[1]):
          if (Q[i,j] >= 0.5226) or (Q[i,j] <= -0.5226):
              flag = False
  return flag


def RGB2YIQ(img):
  r = img[:,:,0]/255
  g = img[:,:,1]/255
  b = img[:,:,2]/255

  Y = (r*0.299+g*0.587+b*0.114)*255
  I = (r*0.595716-g*0.274453-b*0.321263)*255
  Q = (r*0.211456-g*0.522591+b*0.311135)*255

  return(Y,I,Q)


Y,I,Q = RGB2YIQ(arg)

print("Mapa de color Viridis")
plt.imshow(Y, cmap = 'viridis')
plt.colorbar()
# Out:
# Mapa de color Viridis

# %%
print("Mapa de color Prism")
plt.imshow(Y, cmap = 'prism')
plt.colorbar()
# Out:
# Mapa de color Prism
